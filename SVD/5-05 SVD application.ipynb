# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img=cv2.imread('Wild.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (900, 1600, 3)

# %% [markdown]
# convert the image to gray scale

# %%
gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
plt.imshow(gray,cmap='gray')

# %%
U,S,V=np.linalg.svd(gray,full_matrices=False)
print(U.shape,S.shape,V.shape)
# Out:
# (900, 900) (900,) (900, 1600)

# %%
comps=[U.shape[0],100,50,20,10,5,2,1]
fig=plt.figure(figsize=(15,8))
for i in range(len(comps)):
    trans_image=U[:,:comps[i]]@np.diag(S[:comps[i]])@V[:comps[i],:]
    plt.subplot(2,4,i+1)
    plt.imshow(trans_image,cmap='gray')
    plt.title('image n_components'+str(comps[1]))

# %%
# code for random image generation
#0-255
#64*64 = 4094*3 => 12288
x=np.random.randint(0,256,12288).reshape(64,64,3)
plt.imshow(x)

cv2.imwrite('myrandomimage.jpg',x)
# Out:
# True
